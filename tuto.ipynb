# %%
data=("kbeie")
a=len(data)
print(a)
for i in range(len(data)):
    print(data[i])
# Out:
# 5
# k
# b
# e
# i
# e

# %%
ls=[1,2,4,5,6,"onwo",True]
print(type(ls))
print(ls)

ls.append(3)
ls
# Out:
# <class 'list'>
# [1, 2, 4, 5, 6, 'onwo', True]
# [1, 2, 4, 5, 6, 'onwo', True, 3]

# %%
ls={1,2,4,56,3,2,45,6}
ls.add(44)
ls.add(55)
ls
# Out:
# {1, 2, 3, 4, 6, 44, 45, 55, 56}

# %%
n = int(input("Enter your age: "))
if n >= 18:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Eligible

# %%
#ESCAPE SEQUENCE
path = "C:\\Users\\Alice\\Documents"
print(path)
# Out:
# C:\Users\Alice\Documents

# %%
backspace_string = "Hello\b\bWorld"
print(backspace_string)
# Out:
# HelWorld

# %%
#formatted string
s="Hello"
w="world"
formatted_string = "Hello, %s. You are %s years old." % (s, w)
print(formatted_string)
# Out:
# Hello, Hello. You are world years old.

# %%
name = "John"
age = 30
formatted_string = "Hello, {}. You are {} years old.".format(age, name)
print(formatted_string)
# Out:
# Hello, 30. You are John years old.

# %%
name="Pranjal"
age=21
formatted_string=f"Hello my name is {name} and my age is {21}"
print(formatted_string)
# Out:
# Hello my name is Pranjal and my age is 21

# %%
name="Pranjal"
age=21
res="My name is " +name+ " "+ "and my age is "
print(res)
# Out:
# My name is Pranjal and my age is

# %%
path = r'C:\\programfiles\\ln'
print(path)
# Out:
# C:\\programfiles\\ln

# %%
print("John","Doe\n","jno",sep="*", end="-")
# Out:
# John*Doe
# *jno-

# %%
#SWAP of two 
a=3
b=4
# tmp=a
# a=b
# b=tmp
# print(a,b)


# a=a+b
# b=a-b
# a=a-b
# print("a :",a)
# print("b :",b)



a,b=b,a
print("a :",a)
print("b :",b)
# Out:
# a : 4
# b : 3

# %%
string="chitra"
print(string[2::3])
# Out:
#   Cell In[69], line 2
#     print(string[2::3::1])
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('read.csv')
data
# Out:
#                    Department                                Major  \
# 0                      Police                Business/Admin./Mgmt.
# 1                      Police                Business/Admin./Mgmt.
# 2                      Police                Business/Admin./Mgmt.
# 3     Health & Human Services                Business/Admin./Mgmt.
# 4     Health & Human Services                          Other/Misc.
# ...                       ...                                  ...
# 4363                   Police                    Political Science
# 4364     Fire/Rescue Services                                  NaN
# 4365           Liquor Control               Information Technology
# 4366                   Police                          Other/Misc.
# 4367           Transportation  Civil and Environmental Engineering
#
#                         Degree                               School  \
# 0                           AA  Montgomery College Rockville Campus
# ...

# %%
plt.figure(figsize=(15, 10))
data.groupby('Department')['Cost'].mean().plot(kind='bar', color='pink')
plt.title('Average Cost of Courses by Department')
plt.xlabel('Department')
plt.ylabel('Average Cost ($)')
plt.xticks(rotation=90)
plt.yticks(range(0, int(data['Cost'].max()) + 100, 100))  # Setting y-axis ticks spaced by 100 units
plt.grid(axis='y', linestyle='--', alpha=0.9)
# plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['Cost'], bins=10, color='pink', edgecolor='black')
plt.title('Distribution of Course Costs')
plt.xlabel('Cost ($)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data['Cost'].value_counts().sum()
# Out:
# 4368

# %%
average_cost_by_department = data.groupby('Department')['Cost'].mean()
average_cost_by_department
# Out:
# Department
# Animal services                                509.142857
# Board of Elections                             895.000000
# Community Engagement Cluster                  1290.225000
# Community Use Public Facilities                610.845238
# Consumer Protection                            990.000000
# Correction & Rehabilitation                    884.436244
# County Attorney                                395.224000
# County Council                                1525.000000
# County Executive                               336.000000
# Emergency Mgmt & Homeland Security             940.000000
# Environmental Protection                       644.671233
# Finance                                        668.302321
# Fire/Rescue Services                           755.565073
# General Services                               694.799099
# Health & Human Services                        832.628016
# Housing & Community Affairs                    597.574237
# ...

# %%
average_cost_by_department.plot(kind='bar', title='Average Course Cost by Department')
# Out:
# <Axes: title={'center': 'Average Course Cost by Department'}, xlabel='Department'>

# %%
data['Cost'].unique()
# Out:
# array([3.92000e+02, 1.06200e+03, 1.56900e+03, 8.70000e+02, 2.94000e+02,
#        0.00000e+00, 1.83000e+03, 3.36000e+02, 1.46000e+02, 7.53000e+02,
#        3.63340e+02, 1.65300e+03, 5.50000e+02, 4.83330e+02, 7.68000e+02,
#        7.42000e+02, 3.63330e+02, 1.37400e+03, 3.54000e+02, 3.46000e+02,
#        7.98000e+02, 2.34000e+02, 6.36000e+02, 1.82400e+03, 2.61250e+02,
#        2.61500e+02, 4.08750e+02, 1.72500e+03, 3.05000e+02, 1.05000e+02,
#        6.07500e+02, 1.80000e+02, 3.73340e+02, 8.95000e+02, 3.73330e+02,
#        9.15000e+02, 1.12000e+02, 5.40000e+02, 2.12000e+02, 1.64800e+03,
#        4.83340e+02, 8.40000e+02, 7.50000e+02, 1.85000e+02, 4.56000e+02,
#        1.18000e+03, 3.30000e+02, 2.51000e+02, 1.12500e+03, 7.05000e+02,
#        2.24000e+02, 5.05000e+02, 1.57500e+03, 7.80000e+02, 9.00000e+02,
#        1.19500e+03, 1.19000e+03, 6.21000e+02, 1.03500e+03, 6.96000e+02,
#        9.30000e+02, 2.13000e+03, 3.27000e+02, 3.00000e+01, 6.00000e+01,
# ...

# %%
high_cost_courses = data[data['Cost'] > 500]
high_cost_courses
# Out:
#                    Department                    Major  \
# 3     Health & Human Services    Business/Admin./Mgmt.
# 4     Health & Human Services              Other/Misc.
# 5                     Finance    Accounting (Business)
# 9     Health & Human Services               Not Listed
# 12            County Attorney  Health & Human Services
# ...                       ...                      ...
# 4360         General Services                      NaN
# 4361                   Police               Psychology
# 4364     Fire/Rescue Services                      NaN
# 4365           Liquor Control   Information Technology
# 4366                   Police              Other/Misc.
#
#                         Degree                                       School  \
# 3     Masters (MA/MS/MPH/etc.)                       BOWIE STATE UNIVERSITY
# 4     Masters (MA/MS/MPH/etc.)                   Mount St Mary's University
# ...

# %%
unique_departments = data['Department'].unique()
unique_departments
# Out:
# array(['Police', 'Health & Human Services', 'Finance', 'County Attorney',
#        'Community Use Public Facilities', 'Public Information',
#        "State's Attorney", 'General Services', 'Fire/Rescue Services',
#        'Correction & Rehabilitation', 'Transportation',
#        'Housing & Community Affairs', 'County Council',
#        'Technology Services', 'Environmental Protection',
#        'Human Resources', 'Recreation', 'County Executive', 'Libraries',
#        'Consumer Protection', 'Liquor Control', 'Animal services',
#        'Permitting Services', 'Investment Trustees',
#        'Management & Budget', 'Sheriff', 'Community Engagement Cluster',
#        'Procurement', 'Emergency Mgmt & Homeland Security',
#        'Legislative Oversight', 'Human Rights', 'Board of Elections',
#        'Office of Racial Equity and Social Justice',
#        'Office of Labor Relations'], dtype=object)

# %%
avg_cost_by_dept_and_degree = data.groupby(['Department', 'Degree'])['Cost'].mean().reset_index()
print(avg_cost_by_dept_and_degree)

data['Cost'].sum()
# Out:
#              Department                    Degree         Cost
# 0       Animal services  Masters (MA/MS/MPH/etc.)  1830.000000
# 1       Animal services                Non-Degree   346.800000
# 2       Animal services                     Other   260.100000
# 3    Board of Elections         Bachelors (BA/BS)   900.000000
# 4    Board of Elections                Non-Degree   885.000000
# ..                  ...                       ...          ...
# 140      Transportation  Masters (MA/MS/MPH/etc.)  1395.480000
# 141      Transportation                Non-Degree   413.954545
# 142      Transportation                     Other   168.000000
# 143      Transportation               Ph.D. (DCS)  1590.000000
# 144      Transportation               Ph.D. (DDE)  1065.000000
#
# [145 rows x 3 columns]
# 3434396.8899999997

# %%
pivot_table_summary = data.pivot_table(values='Cost', index='Department', columns='Degree', aggfunc='mean')
pivot_table_summary = data.pivot_table(values='Cost', index='Department', columns='Degree', aggfunc='mean')
pivot_table_summary
# Fill NaN values with 0
pivot_table_summary_filled = pivot_table_summary.fillna(0)
pivot_table_summary_filled
# Out:
# Degree                                              AA  Bachelors (BA/BS)  \
# Department
# Animal services                               0.000000           0.000000
# Board of Elections                            0.000000         900.000000
# Community Engagement Cluster                  0.000000        1325.281250
# Community Use Public Facilities             392.125000           0.000000
# Consumer Protection                           0.000000         990.000000
# Correction & Rehabilitation                 474.211000         777.998901
# County Attorney                             288.506667         652.125000
# County Council                                0.000000           0.000000
# County Executive                              0.000000         336.000000
# Emergency Mgmt & Homeland Security            0.000000           0.000000
# Environmental Protection                    352.300000         715.833333
# ...

# %%
courses_grouped_by_school_and_degree = data.groupby(['School', 'Degree']).size().reset_index(name='Count')
# print("Courses Grouped by School and Degree:\n", courses_grouped_by_school_and_degree)
# courses_grouped_by_school_and_degree
courses_grouped_by_school_and_degree = data.groupby(['School', 'Degree']).size().reset_index(name='Count')

# print("Courses Grouped by School and Degree:\n", courses_grouped_by_school_and_degree)

# Filter for Academia School for certificate degree with count 18
filtered_data = data[(data['School'] == 'ACADEMI') & (data['Degree'] == 'Certificate')]

filtered_data
# Out:
#      Department             Major       Degree   School  \
# 356      Police       Job Related  Certificate  ACADEMI
# 370      Police       Job Related  Certificate  ACADEMI
# 525      Police  Criminal Justice  Certificate  ACADEMI
# 925      Police     Not Specified  Certificate  ACADEMI
# 930      Police       Other/Misc.  Certificate  ACADEMI
# 1370     Police     Not Specified  Certificate  ACADEMI
# 1373     Police     Not Specified  Certificate  ACADEMI
# 1942     Police     Public Safety  Certificate  ACADEMI
# 1952     Police     Public Safety  Certificate  ACADEMI
# 1965     Police     Public Safety  Certificate  ACADEMI
# 1973     Police     Public Safety  Certificate  ACADEMI
# 2040     Police       Job Related  Certificate  ACADEMI
# 2098     Police     Public Safety  Certificate  ACADEMI
# 2629     Police       Job Related  Certificate  ACADEMI
# 2669     Police       Job Related  Certificate  ACADEMI
# 2690     Police       Job Related  Certificate  ACADEMI
# ...

# %%
plt.figure(figsize=(40, 36))
data.boxplot(column='Cost', by='Degree')
plt.xticks(rotation=90)
plt.title('Boxplot of Course Costs by Degree')
plt.suptitle('')  # Remove the automatic 'Boxplot grouped by ...' title
plt.xlabel('Degree')
plt.ylabel('Cost')
plt.show()

# %%
course_distribution_by_degree = data['Degree'].value_counts()

# Create a larger frame
plt.figure(figsize=(10, 8))

# Pie Chart
course_distribution_by_degree.plot(kind='pie', autopct='%1.1f%%', startangle=100)
plt.title('Course Distribution by Degree')
plt.ylabel('')  # Hide y-label
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(20, 20))
plt.scatter(data['School'], data['Cost'], color='green')
plt.title('Course Cost vs. School')
plt.xlabel('School')
plt.ylabel('Cost')
plt.xticks(rotation=90)
plt.show()

# %%
montgomery_college = df[df['School'].str.contains('Montgomery College', case=False, na=False)]

# Select the first 200 rows (if available)
montgomery_college_first_200 = montgomery_college.head(200)
montgomery_college_first_200
# Out:
#                   Department                        Major             Degree  \
# 0                     Police        Business/Admin./Mgmt.                 AA
# 1                     Police        Business/Admin./Mgmt.                 AA
# 2                     Police        Business/Admin./Mgmt.                 AA
# 6                     Police        Business/Admin./Mgmt.                 AA
# 50            Transportation         Agricultural General              Other
# 53   Health & Human Services        Business/Admin./Mgmt.                 AA
# 62           County Attorney                          NaN         Non-Degree
# 63           County Attorney                          NaN         Non-Degree
# 80            Transportation         Agricultural General              Other
# 85                   Finance                          NaN         Non-Degree
# 137         County Executive        Business/Admin./Mgmt.  Bachelors (BA/BS)
# ...
